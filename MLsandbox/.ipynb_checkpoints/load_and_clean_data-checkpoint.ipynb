# %%
import pandas as pd
import numpy as np
from importlib import import_module
from MLsandbox import model_dict  # import ModelDict tools (developed by Nicole)

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('sample_data.csv', sep=',', header=False, index_col=0)
df.head()
# Out:
#        site_id  strategy_id list_type  line_id  advertiser_id adv_vertical  \
# 24152    82932       313729   testing    20049            206       Travel
# 32593    90474       313729   testing    20049            206       Travel
# 39061    92345       313729   testing    20049            206       Travel
# 39283    92415       313729   testing    20049            206       Travel
# 39287    92425       313729   testing    20049            206       Travel
#
#             opti_name  cpa_goal  cpm_price  impression_limit  \
# 24152  Nicole Abruzzo         0       3.95             10000
# 32593  Nicole Abruzzo         0       3.95             10000
# 39061  Nicole Abruzzo         0       3.95             10000
# 39283  Nicole Abruzzo         0       3.95             10000
# 39287  Nicole Abruzzo         0       3.95             10000
#
#                ...           win_rate_strat  cvr_strat       cvr  line_cvr  \
# ...

# %% [markdown]
# ## Check for missing values and balanced data
